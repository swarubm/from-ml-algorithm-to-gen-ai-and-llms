# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

# %%
data = fetch_20newsgroups(subset='train', categories=['comp.graphics', 'sci.med'])

# %%
vectorizer = CountVectorizer()

# %%
x = vectorizer.fit_transform(data.data)
y = data.target

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# mnb = MultinomialNB()

# %%
mnb.fit(x_train,y_train)

# %%
y_pred = mnb.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)

# %% [raw]
# count vectorizer
# this convert textual data into a matrix of token counts,
# where each row corresponds to a document and each column represent the count of a specific word in that document.
# step is essential to transform the textual data into a format suitable for multinomial naive bayes
