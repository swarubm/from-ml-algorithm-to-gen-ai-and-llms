# %%
import pandas as pd 
import numpy as np

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
breast_cancer = load_breast_cancer()

# %%
x = breast_cancer.data
y = breast_cancer.target

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(x,y)
# Out:
# LinearDiscriminantAnalysis()

# %%
x_lda = lda.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_lda,y,test_size=0.2,random_state=42)

# %% [markdown]
# in the code x and y represent the input charecterstics and target variables of the wisconsin breast cancer dataset,
# respectively.we then initialize the lda model using linear descriminant analysis() and fit it to the dataset using fit(x,y).finally we transform the dataset using the LDA model using the transform(x) method.

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
